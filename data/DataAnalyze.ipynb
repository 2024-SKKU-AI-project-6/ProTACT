# %%
import pandas as pd
import numpy as np

# %%
train_data_path = './cross_prompt_attributes/1/train.pk'
dev_data_path = './cross_prompt_attributes/1/dev.pk'
test_data_path = './cross_prompt_attributes/1/test.pk'
features_path = './hand_crafted_v3.csv'
readability_path ='./allreadability.pickle'
embedding_path = '../embeddings/glove.6B.50d.txt'
prompt_path = './prompt_info_pp.csv'

# %%
x_train = pd.read_pickle(train_data_path)
x_train_df = pd.DataFrame(x_train)
x_dev = pd.read_pickle(dev_data_path)
x_dev_df = pd.DataFrame(x_dev)
x_test = pd.read_pickle(test_data_path)
x_test_df = pd.DataFrame(x_test)
prompt = pd.read_csv(prompt_path)
prompt_df = pd.DataFrame(prompt)
features = pd.read_csv(features_path)
features_df = pd.DataFrame(features)
readability = pd.read_pickle(readability_path)
readability_df = pd.DataFrame(readability)

# %%
1785+1800+1726+1772+1805+1800+1569+723
# Out:
# 12980

# %%
prompt_df
# Out:
#    prompt_id                                             prompt
# 0          1  people use computers everyone agrees benefits ...
# 1          2  censorship libraries . us think book hope none...
# 2          3  write response explains features setting affec...
# 3          4  read last paragraph story . come back saeng vo...
# 4          5  describe mood created author memoir . support ...
# 5          6  based excerpt describe obstacles builders empi...
# 6          7  write patience . patient means understanding t...
# 7          8  understand benefits laughter . example someone...

# %%
features_df
# Out:
#        item_id  prompt_id  mean_word  word_var  mean_sent    sent_var  \
# 0            1          1   4.400593  5.842492  21.062500  171.308594
# 1            2          1   4.353222  5.469506  20.950000  142.247500
# 2            3          1   4.405018  5.545638  19.928571  184.637755
# 3            4          1   4.868321  6.415867  19.407407  135.722908
# 4            5          1   4.408602  5.450249  15.500000   43.516667
# ...        ...        ...        ...       ...        ...         ...
# 12973    21626          8   4.082840  3.922132  31.296296  220.727023
# 12974    21628          8   3.943119  3.620618  15.571429  181.673469
# 12975    21629          8   4.394608  5.746245  19.902439  251.063653
# 12976    21630          8   4.211744  5.896446  14.410256   52.395792
# 12977    21633          8   4.243590  6.090237  16.137931   30.187872
#
#        ess_char_len  word_count  prep_comma  unique_word  ...       WDT  \
# 0              1483         337          71          117  ...  0.000000
# 1              1824         419          70          125  ...  0.002146
# 2              1229         279          41          113  ...  0.000000
# 3              2551         524          77          179  ...  0.003247
# 4              2050         465          56          128  ...  0.005780
# ...             ...         ...         ...          ...  ...       ...
# 12973          3450         845         136          221  ...  0.001963
# 12974          2149         545          72          119  ...  0.002928
# 12975          3586         816         151          252  ...  0.006917
# 12976          2367         562         109          160  ...  0.001439
# 12977          1986         468          81          154  ...  0.009208
#
#              DT        CD        NN        TO        JJ       VBP        RP  \
# 0      0.051546  0.000000  0.144330  0.025773  0.048969  0.030928  0.007732
# 1      0.075107  0.008584  0.122318  0.017167  0.042918  0.036481  0.004292
# 2      0.085714  0.006349  0.123810  0.025397  0.047619  0.076190  0.009524
# 3      0.069805  0.000000  0.126623  0.024351  0.066558  0.040584  0.001623
# 4      0.104046  0.009634  0.131021  0.040462  0.042389  0.036609  0.001927
# ...         ...       ...       ...       ...       ...       ...       ...
# 12973  0.060844  0.010795  0.095191  0.019627  0.049068  0.035329  0.005888
# 12974  0.064422  0.007321  0.124451  0.021962  0.060029  0.020498  0.007321
